# %%
#Alisha Rhodes
#12/7/2025
#13.1 Write the current date as a string to the text file today.txt.

from datetime import date, datetime

# Pull today

today = date.today()

# transfer into text.txt

with open("today.txt", "w") as file:
     file.write(str(today))

# %%
#Alisha Rhodes
#12/7/2025
#13.2 Read the text file today.txt into the string today_string.

with open("today.txt", "r") as file:
     today_string = file.read()

# %%
#Alisha Rhodes
#12/7/2025
#13.3 Parse the date from today_string.

parsed_date = datetime.strptime(today_string, "%Y-%m-%d").date()
print("Date:", parsed_date)
# Out:
# Date: 2025-12-07

# %%
#Alisha Rhodes
#12/7/2025
#15.1 Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between zero and one, print the current time, and then exit.

import multiprocessing as mp
import random
import time
from datetime import datetime

def process(name: str):
    random.seed(mp.current_process().pid + time.time()) #random number generator function
    delay = random.uniform(0,1)
    time.sleep(delay)

    now = datetime.now().strftime("%Y-%m-%d %H:%M") #pull local time and converting to string 
    print(f"[{name}] Slept {delay:.3f}s | Time: {now}")

if __name__ == "__main__":
    mp.set_start_method("spawn", force=True)
    
    processes = [
        mp.Process(target=process, args=("Process-1",)),
        mp.Process(target=process, args=("Process-2",)),
        mp.Process(target=process, args=("Process-3",)),
    ]

    for p in processes:
        p.start()

    for p in processes:
        p.join()

    print("All processes completed.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 28
#      21 processes = [
#      22     mp.Process(target=process, args=("Process-1",)),
#      23     mp.Process(target=process, args=("Process-2",)),
#      24     mp.Process(target=process, args=("Process-3",)),
#      25 ]
#      27 for p in processes:
# ---> 28     p.start()
#      30 for p in processes:
#      31     p.join()
#
# File /lib/python3.13/multiprocessing/process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File /lib/python3.13/multiprocessing/context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File /lib/python3.13/multiprocessing/context.py:289, in SpawnProcess._Popen(process_obj)
#     286 @staticmethod
#     287 def _Popen(process_obj):
#     288     from .popen_spawn_posix import Popen
# --> 289     return Popen(process_obj)
#
# File /lib/python3.13/multiprocessing/popen_spawn_posix.py:32, in Popen.__init__(self, process_obj)
#      30 def __init__(self, process_obj):
#      31     self._fds = []
# ---> 32     super().__init__(process_obj)
#
# File /lib/python3.13/multiprocessing/popen_fork.py:20, in Popen.__init__(self, process_obj)
#      18 self.returncode = None
#      19 self.finalizer = None
# ---> 20 self._launch(process_obj)
#
# File /lib/python3.13/multiprocessing/popen_spawn_posix.py:39, in Popen._launch(self, process_obj)
#      38 def _launch(self, process_obj):
# ---> 39     from . import resource_tracker
#      40     tracker_fd = resource_tracker.getfd()
#      41     self._fds.append(tracker_fd)
#
# File /lib/python3.13/multiprocessing/resource_tracker.py:41
#      35 _CLEANUP_FUNCS = {
#      36     'noop': cleanup_noop,
#      37     'dummy': lambda name: None,  # Dummy resource used in tests
#      38 }
#      40 if os.name == 'posix':
# ---> 41     import _multiprocessing
#      42     import _posixshmem
#      44     # Use sem_unlink() to clean up named semaphores.
#      45     #
#      46     # sem_unlink() may be missing if the Python build process detected the
#      47     # absence of POSIX named semaphores. In that case, no named semaphores were
#      48     # ever opened, so no cleanup would be necessary.
#
# ModuleNotFoundError: No module named '_multiprocessing'

# %%
#Ran in VS Code without issues. Could be a version issue in Jupyter
