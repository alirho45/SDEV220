# %%
# Seconds per hour calculation
60*60
# Out:
# 3600

# %%
# Assigning variables 
seconds_per_minute = 60
minutes_per_hour = 60
seconds_per_hour =  seconds_per_minute * minutes_per_hour
seconds_per_day = seconds_per_hour * 24

# %%
# Calculate seconds in a day using the variable
seconds_in_day = seconds_per_hour * 24

# %%
# Floating-point division
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %%
# Integer division
seconds_per_day // seconds_per_hour
# Out:
# 24

# %% [markdown]
# Did this number agree with the floating-point value from the previous question, aside from the final .0? Yes, it did. The Results are the same.
