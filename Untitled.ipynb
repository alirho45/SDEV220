# %%
PS C:\Users\Ali-R\Desktop\project> python -m unittest test.py
F.
======================================================================
FAIL: test_list_fraction (test.TestSum.test_list_fraction)
Test that it can sum a list of fractions
----------------------------------------------------------------------
Traceback (most recent call last):
  File "C:\Users\Ali-R\Desktop\project\test.py", line 16, in test_list_fraction
    self.assertEqual(result, 1)
    ~~~~~~~~~~~~~~~~^^^^^^^^^^^
AssertionError: Fraction(9, 10) != 1

# %%
Here the Fraction test failed while the integrer test passed. The Test output is "F." Meaning the unitest discovered the Fraction test first, determined
determind that it failes and then acknoledged the integer test as passed. The AssertionError tells me that the fraction of 9 and 10 in not equal 1.

# %%
..
----------------------------------------------------------------------
Ran 2 tests in 0.000s

OK

# %%
I have then corrected the file, and ran the test again. ".." indicates both tests have passed and the Test puts out "OK"
